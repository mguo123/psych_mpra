# %% [markdown]
# # 9A_omim_enrichment
#
# 01/21/2020
# get omim enrichment
#
# monogenic vs polygenic diseases
#
# updated with psych encode eqtl genes

# %%
import pandas as pd
import os, glob
import re

# %%
save_dir = 'omim_enrichment/'

# %% [markdown]
# # A. Preprocessing

# %% [markdown]
# ## 1 polygenic mpra egene disease_files

# %%
dz_to_abbr_dict = {
    'schizo':'SCZ',
    'bipolar':'BPD',
    'personality':'BPLD',
    'traum':'PTSD',
    'anxiety':'GAD',
    'depress':'MDD',
    'ocd':'OCD',
    'panic':'PD',
    'autism':'ASD',
    'attent':'ADHD',
}

# %%
# polygenic genesets
gene_files = glob.glob('D_mpraanalyze_barcode_allelic/egene_gtex_psychencode/*txt')
gene_files
# Out:
# ['D_mpraanalyze_barcode_allelic/egene_gtex_psychencode/all.txt',
#  'D_mpraanalyze_barcode_allelic/egene_gtex_psychencode/BPD.txt',
#  'D_mpraanalyze_barcode_allelic/egene_gtex_psychencode/PTSD.txt',
#  'D_mpraanalyze_barcode_allelic/egene_gtex_psychencode/SCZ.txt',
#  'D_mpraanalyze_barcode_allelic/egene_gtex_psychencode/ASD.txt',
#  'D_mpraanalyze_barcode_allelic/egene_gtex_psychencode/BLPD.txt',
#  'D_mpraanalyze_barcode_allelic/egene_gtex_psychencode/MDD.txt',
#  'D_mpraanalyze_barcode_allelic/egene_gtex_psychencode/OCD.txt',
#  'D_mpraanalyze_barcode_allelic/egene_gtex_psychencode/PD.txt',
#  'D_mpraanalyze_barcode_allelic/egene_gtex_psychencode/GAD.txt',
#  'D_mpraanalyze_barcode_allelic/egene_gtex_psychencode/ADHD.txt']

# %%
polydz_to_geneset = {}
for file in sorted(gene_files):
    dz = os.path.basename(file).split('.')[0]
    polydz_to_geneset[dz] = sorted(set(pd.read_table(file, header=None).iloc[:,0]))
    print(dz, len(polydz_to_geneset[dz]) )
# Out:
# ADHD 67
# ASD 2
# BLPD 24
# BPD 180
# GAD 30
# MDD 129
# OCD 28
# PD 4
# PTSD 9
# SCZ 433
# all 619

# %% [markdown]
# ## 2. monogenic disease file preprocessing

# %%
omim_dir = '/Users/mguo123/Google Drive/0_altman/db/omim/20210121/'
glob.glob(omim_dir+'*')
# Out:
# ['/Users/mguo123/Google Drive/0_altman/db/omim/20210121/Icon\r',
#  '/Users/mguo123/Google Drive/0_altman/db/omim/20210121/mim2gene.txt',
#  '/Users/mguo123/Google Drive/0_altman/db/omim/20210121/genemap2.txt',
#  '/Users/mguo123/Google Drive/0_altman/db/omim/20210121/mimTitles.txt',
#  '/Users/mguo123/Google Drive/0_altman/db/omim/20210121/morbidmap.txt']

# %%
mim2gene = pd.read_table(os.path.join(omim_dir, 'mim2gene.txt'), header=4).dropna()
num_omim_genes = mim2gene['Approved Gene Symbol (HGNC)'].unique().shape#15999

# %%
# with open(os.path.join(omim_dir, 'morbidmap.txt'), 'r') as f:
#     for idx, line in enumerate(f.readlines()):
#         print(line.strip().split('\t'))

# %%
morbid_map = pd.read_table(os.path.join(omim_dir, 'morbidmap.txt'), header=3).dropna()
# Clean number ids and braces
morbid_map['phenotype_cleaned'] = morbid_map['# Phenotype'].apply(lambda x: re.split(', [0-9]',x)[0].strip('{}?')).to_list()
# Clean first #s for grouping
morbid_map['phenotype_cleaned2'] = morbid_map.phenotype_cleaned.apply(lambda x: re.sub(r'[,()\d]+$', '', x.strip()).strip()).to_list()
# Clearn more for grouping
morbid_map['phenotype_cleaned3'] = morbid_map['phenotype_cleaned2'].apply(lambda str_disease: 
                                       ' '.join([ x.strip(', ()') for x in str_disease.split(' ') if not x.strip(', ()').isnumeric()])).to_list()

print(morbid_map.shape, morbid_map.phenotype_cleaned.unique().shape,
      morbid_map.phenotype_cleaned2.unique().shape, morbid_map.phenotype_cleaned3.unique().shape)
# Out:
# (8052, 7) (6873,) (5291,) (4797,)

# %% [markdown]
# manually pick neuro relevant monogenic diseases

# %%
with open('omim_enrichment/phenotype_cleaned3_all.txt','w') as f:
    for x in sorted(morbid_map.phenotype_cleaned3.unique()):
        f.write(x+'\n')

# %% [markdown]
# in the meantime get diseases --> gene lists

# %%
morbid_map[:5]
# Out:
#                                          # Phenotype  \
# 0       17,20-lyase deficiency, isolated, 202110 (3)
# 1  17-alpha-hydroxylase/17,20-lyase deficiency, 2...
# 2   2,4-dienoyl-CoA reductase deficiency, 616034 (3)
# 3     2-aminoadipic 2-oxoadipic aciduria, 204750 (3)
# 4              2-methylbutyrylglycinuria, 610006 (3)
#
#                       Gene Symbols  MIM Number Cyto Location  \
# 0          CYP17A1, CYP17, P450C17    609300.0      10q24.32
# 1          CYP17A1, CYP17, P450C17    609300.0      10q24.32
# 2            NADK2, C5orf33, DECRD    615787.0        5p13.2
# 3  DHTKD1, KIAA1630, AMOXAD, CMT2Q    614984.0         10p14
# 4                    ACADSB, SBCAD    600301.0      10q26.13
#
#                              phenotype_cleaned  \
# 0             17,20-lyase deficiency, isolated
# 1  17-alpha-hydroxylase/17,20-lyase deficiency
# 2         2,4-dienoyl-CoA reductase deficiency
# 3           2-aminoadipic 2-oxoadipic aciduria
# 4                    2-methylbutyrylglycinuria
#
#                             phenotype_cleaned2  \
# 0             17,20-lyase deficiency, isolated
# 1  17-alpha-hydroxylase/17,20-lyase deficiency
# 2         2,4-dienoyl-CoA reductase deficiency
# 3           2-aminoadipic 2-oxoadipic aciduria
# 4                    2-methylbutyrylglycinuria
#
#                             phenotype_cleaned3
# 0              17,20-lyase deficiency isolated
# 1  17-alpha-hydroxylase/17,20-lyase deficiency
# 2         2,4-dienoyl-CoA reductase deficiency
# 3           2-aminoadipic 2-oxoadipic aciduria
# 4                    2-methylbutyrylglycinuria

# %%
morbid_map_grouped = morbid_map.groupby('phenotype_cleaned3').agg({'Gene Symbols': lambda arr: ', '.join(arr),
                                            'MIM Number': lambda arr: '|'.join([str(int(x)) for x in arr]),
                                            'Cyto Location': lambda arr: '|'.join(arr)}).reset_index()
print(morbid_map_grouped.shape)
morbid_map_grouped[:5]
# Out:
# (4797, 4)
#                             phenotype_cleaned3  \
# 0              17,20-lyase deficiency isolated
# 1  17-alpha-hydroxylase/17,20-lyase deficiency
# 2         2,4-dienoyl-CoA reductase deficiency
# 3           2-aminoadipic 2-oxoadipic aciduria
# 4                    2-methylbutyrylglycinuria
#
#                       Gene Symbols MIM Number Cyto Location
# 0          CYP17A1, CYP17, P450C17     609300      10q24.32
# 1          CYP17A1, CYP17, P450C17     609300      10q24.32
# 2            NADK2, C5orf33, DECRD     615787        5p13.2
# 3  DHTKD1, KIAA1630, AMOXAD, CMT2Q     614984         10p14
# 4                    ACADSB, SBCAD     600301      10q26.13

# %%
morbid_map_grouped['geneset'] = morbid_map_grouped['Gene Symbols'].apply(lambda x: sorted(set(x.split(', '))))
morbid_map_grouped['len_geneset'] = morbid_map_grouped.geneset.map(len)
morbid_map_grouped.sort_values('len_geneset', ascending=False)
# Out:
#                               phenotype_cleaned3  \
# 1219  Developmental and epileptic encephalopathy
# 3853                        Retinitis pigmentosa
# 1165                Deafness autosomal recessive
# 620                       Cardiomyopathy dilated
# 2133                            Immunodeficiency
# ...                                          ...
# 3793                       Radial ray deficiency
# 589               CPT deficiency hepatic type IA
# 3049                               Narcolepsy 5}
# 3048                               Narcolepsy 4}
# 2946   Myasthenia gravis with thymus hyperplasia
#
#                                            Gene Symbols  \
# 1219  ST3GAL3, SIAT6, ST3GALII, MRT12, DEE15, GUF1, ...
# 3853  OFD1, CXorf5, SGBS2, JBTS10, RP23, TTC8, BBS8,...
# 1165  GRXCR2, DFNB101, EPS8, DFNB102, CLIC5, DFNB103...
# 620   EYA4, DFNA10, CMD1J, CSRP3, CRP3, CLP, CMD1M, ...
# 2133  UNC119, HRG4, IMD13, TNFRSF4, TXGP1L, OX40, AC...
# ...                                                 ...
# 3793                                               RRDX
# 589                                               CPT1A
# 3049                                             NRCLP5
# 3048                                             NRCLP4
# 2946                                              MYAS1
#
#                                              MIM Number  \
# 1219  606494|617064|610044|603709|618904|154200|3003...
# 3853  300170|608132|613598|180290|604043|614068|6002...
# 1165  615762|600206|607293|611410|602336|612959|6031...
# 620   603550|600824|191044|614518|150330|102573|1256...
# 2133  604011|600315|153390|186780|603517|605047|6023...
# ...                                                 ...
# 3793                                             300378
# 589                                              600528
# 3049                                             612851
# 3048                                             612417
# 2946                                             607085
#
#                                           Cyto Location  \
# 1219  1p34.1|4p12|1q31.3|7q21.12|3p21.31|2p15|Xp21.3...
# 3853  Xp22.2|14q31.3|2p23.3|10q11.22|1q32.3|14q24.3|...
# 1165  5q32|12p12.3|6p21.1|6p22.3|1p31.3|8q22.1|14q12...
# 620   6q23.2|11p15.1|19q13.42|7q21.2|1q22|1q43|18q12...
# 2133  17q11.2|1p36.33|1p35.2|1q24.2|1p22.3|11p15.5|2...
# ...                                                 ...
# 3793                                           Xq24-q25
# 589                                             11q13.3
# 3049                                            14q11.2
# 3048                                              22q13
# 2946                                             6p21.3
#
#                                                 geneset  len_geneset
# 1219  [AARS, AARS1, ACTL6B, ADAM22, ALG13, AP3B2, AR...          280
# 3853  [ABCA4, ABCR, AC133, AGBL5, AHR, ANT1, ARFL3, ...          240
# 1165  [ADCY1, AUNB1, BDP1, C19orf46, C21orf29, C6orf...          211
# 620   [ABCC9, ACNINV3, ACTC1, ACTN2, AD3, AD4, ARVC1...          165
# 2133  [ACT35, ADMIO2, AGM1, AGM7, AGMX2, AMKL, APDS,...          160
# ...                                                 ...          ...
# 3793                                             [RRDX]            1
# 589                                             [CPT1A]            1
# 3049                                           [NRCLP5]            1
# 3048                                           [NRCLP4]            1
# 2946                                            [MYAS1]            1
#
# [4797 rows x 6 columns]

# %%
display(morbid_map_grouped[morbid_map_grouped.phenotype_cleaned3.str.lower().str.contains('person')])
list_lists = morbid_map_grouped[morbid_map_grouped.phenotype_cleaned3.str.lower().str.contains('person')].geneset.to_list()
sorted(set([l for sublist in list_lists for l in sublist]    ))
# Out:
#                      phenotype_cleaned3       Gene Symbols MIM Number  \
# 267  Anxiety-related personality traits  SLC6A4, HTT, OCD1     182138
#
#     Cyto Location              geneset  len_geneset
# 267       17q11.2  [HTT, OCD1, SLC6A4]            3
# ['HTT', 'OCD1', 'SLC6A4']

# %%
morbid_map_grouped.to_csv(os.path.join(save_dir, 'morbid_map_grouped_cleaned3.csv'))

# %% [markdown]
# ## 3. combine gene set lists

# %%
monodz_to_geneset = pd.Series(morbid_map_grouped.geneset.values, index=morbid_map_grouped.phenotype_cleaned3).to_dict()

# %%
# takes a while (5000*10 = 50,000 rows)
mono_poly_dz_df = pd.DataFrame(columns=['mono_dz','polydz','mono_geneset', 'poly_geneset','len_mono', 'len_poly'])
idx = 0
for polydz, poly_geneset in polydz_to_geneset.items():
    for mono_dz, mono_geneset in monodz_to_geneset.items():
        mono_poly_dz_df.at[idx, 'mono_dz'] = mono_dz
        mono_poly_dz_df.at[idx, 'polydz'] = polydz
        mono_poly_dz_df.at[idx, 'mono_geneset'] = mono_geneset
        mono_poly_dz_df.at[idx, 'poly_geneset'] = poly_geneset
        mono_poly_dz_df.at[idx, 'len_mono'] = len(mono_geneset)
        mono_poly_dz_df.at[idx, 'len_poly'] = len(poly_geneset)
        idx+=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_value(self, index, col, value, takeable)
#    2885             engine = self.index._engine
# -> 2886             engine.set_value(series._values, index, value)
#    2887             return self
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 5595
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-1103e8cf72cd> in <module>
#       4 for polydz, poly_geneset in polydz_to_geneset.items():
#       5     for mono_dz, mono_geneset in monodz_to_geneset.items():
# ----> 6         mono_poly_dz_df.at[idx, 'mono_dz'] = mono_dz
#       7         mono_poly_dz_df.at[idx, 'polydz'] = polydz
#       8         mono_poly_dz_df.at[idx, 'mono_geneset'] = mono_geneset
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#    2213         key = list(self._convert_key(key, is_setter=True))
#    2214         key.append(value)
# -> 2215         self.obj._set_value(*key, takeable=self._takeable)
#    2216
#    2217
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_value(self, index, col, value, takeable)
#    2892                 self.iloc[index, col] = value
#    2893             else:
# -> 2894                 self.loc[index, col] = value
#    2895             self._item_cache.pop(col, None)
#    2896
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     203             key = com.apply_if_callable(key, self.obj)
#     204         indexer = self._get_setitem_indexer(key)
# --> 205         self._setitem_with_indexer(indexer, value)
#     206
#     207     def _validate_key(self, key, axis: int):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     389                     index = self.obj._get_axis(i)
#     390                     labels = index.insert(len(index), key)
# --> 391                     self.obj._data = self.obj.reindex(labels, axis=i)._data
#     392                     self.obj._maybe_update_cacher(clear=True)
#     393                     self.obj._is_copy = None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     219         @wraps(func)
#     220         def wrapper(*args, **kwargs):
# --> 221             return func(*args, **kwargs)
#     222
#     223         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    3959         kwargs.pop("axis", None)
#    3960         kwargs.pop("labels", None)
# -> 3961         return super().reindex(**kwargs)
#    3962
#    3963     def drop(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4512         # perform the reindex on the axes
#    4513         return self._reindex_axes(
# -> 4514             axes, level, limit, tolerance, method, fill_value, copy
#    4515         ).__finalize__(self)
#    4516
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3847         if index is not None:
#    3848             frame = frame._reindex_index(
# -> 3849                 index, method, copy, level, fill_value, limit, tolerance
#    3850             )
#    3851
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    3869             copy=copy,
#    3870             fill_value=fill_value,
# -> 3871             allow_dups=False,
#    3872         )
#    3873
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4575                 fill_value=fill_value,
#    4576                 allow_dups=allow_dups,
# -> 4577                 copy=copy,
#    4578             )
#    4579
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1265                     ),
#    1266                 )
# -> 1267                 for blk in self.blocks
#    1268             ]
#    1269
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#    1265                     ),
#    1266                 )
# -> 1267                 for blk in self.blocks
#    1268             ]
#    1269
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1312
#    1313         new_values = algos.take_nd(
# -> 1314             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1315         )
#    1316
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1719         arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#    1720     )
# -> 1721     func(arr, indexer, out, fill_value)
#    1722
#    1723     if flip_order:
#
# KeyboardInterrupt:

# %%
mono_poly_dz_df['len_overlap'] = mono_poly_dz_df.apply(lambda row: len(set(row.mono_geneset).intersection(row.poly_geneset)),axis=1)

# %%
mono_poly_dz_df_filt = mono_poly_dz_df[mono_poly_dz_df.len_overlap!=0].sort_values('len_overlap',ascending=False)
mono_poly_dz_df_filt.shape, mono_poly_dz_df.shape

# %% [markdown]
# # if don't want to do big compute then just load in saved version

# %%
import ast
mono_poly_dz_df = pd.read_csv(os.path.join(save_dir,'mono_poly_dz_df_filt.csv'),index_col=0)
mono_poly_dz_df_filt = mono_poly_dz_df[mono_poly_dz_df.len_overlap!=0].sort_values('len_overlap',ascending=False)
mono_poly_dz_df_filt['mono_geneset'] = mono_poly_dz_df_filt['mono_geneset'].apply(lambda x: ast.literal_eval(x))
mono_poly_dz_df_filt['poly_geneset'] = mono_poly_dz_df_filt['poly_geneset'].apply(lambda x: ast.literal_eval(x))
mono_poly_dz_df_filt['overlap'] = mono_poly_dz_df_filt.apply(lambda row: '|'.join(sorted(set(row.mono_geneset).intersection(row.poly_geneset))),axis=1)# mono_poly_dz_df_filt['intersect_genes'] = mono_poly_dz_df_filt.apply(lambda x:
#                                                                     set(x['mono_geneset']).intersectio

# %%
mono_poly_dz_df_filt
# Out:
#                                           mono_dz  poly_dz  \
# 1219   Developmental and epileptic encephalopathy      NaN
# 44817                     Galloway-Mowat syndrome      NaN
# 1644                      Galloway-Mowat syndrome      NaN
# 4075       Spastic paraplegia autosomal recessive      NaN
# 2283                             Joubert syndrome      NaN
# ...                                           ...      ...
# 47281                      Spinocerebellar ataxia      NaN
# 45886      Mental retardation autosomal recessive      NaN
# 4108                       Spinocerebellar ataxia      NaN
# 2713       Mental retardation autosomal recessive      NaN
# 44392  Developmental and epileptic encephalopathy      NaN
#
#                                             mono_geneset  \
# 1219   [AARS, AARS1, ACTL6B, ADAM22, ALG13, AP3B2, AR...
# 44817  [FLJ20411, GAMOS1, GAMOS3, GAMOS4, GAMOS5, GAM...
# 1644   [FLJ20411, GAMOS1, GAMOS3, GAMOS4, GAMOS5, GAM...
# 4075   [ALS5, AP4B1, AP4E1, AP4M1, AP4S1, AP5Z1, ARL6...
# 2283   [3H11AG, ACLS, AGBK, AHI1, ALS2CR4, ARFL3, ARL...
# ...                                                  ...
# 47281  [ADMD, AFG3L2, ASL13, ATX1, ATX2, ATXN1, ATXN1...
# 45886  [2E4, ADAT3, ANK3, BB1, BSSP3, C12orf4, C17orf...
# 4108   [ADMD, AFG3L2, ASL13, ATX1, ATX2, ATXN1, ATXN1...
# 2713   [2E4, ADAT3, ANK3, BB1, BSSP3, C12orf4, C17orf...
# 44392  [AARS, AARS1, ACTL6B, ADAM22, ALG13, AP3B2, AR...
#
#                                             poly_geneset  len_mono  len_poly  \
# 1219   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...       280       429
# 44817  [ABCB9, ABCC8, ABHD16A, ABT1, AGER, AGT, AIF1,...        21       308
# 1644   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...        21       429
# 4075   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...       137       429
# 2283   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...       127       429
# ...                                                  ...       ...       ...
# 47281  [ABCB9, ABCC8, ABHD16A, ABT1, AGER, AGT, AIF1,...       124       308
# 45886  [ABCB9, ABCC8, ABHD16A, ABT1, AGER, AGT, AIF1,...       151       308
# 4108   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...       124       429
# 2713   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...       151       429
# 44392  [ABCB9, ABCC8, ABHD16A, ABT1, AGER, AGT, AIF1,...       280       308
#
#        polydz  len_overlap  hypergeom_pval  pval_adj poly_dz_abbr  \
# 1219      all            3        0.923193       1.0          NaN
# 44817  schizo            2        0.036508       1.0          SCZ
# 1644      all            2        0.066043       1.0          NaN
# 4075      all            2        0.765868       1.0          NaN
# 2283      all            2        0.728285       1.0          NaN
# ...       ...          ...             ...       ...          ...
# 47281  schizo            1        0.836493       1.0          SCZ
# 45886  schizo            1        0.889928       1.0          SCZ
# 4108      all            1        0.920311       1.0          NaN
# 2713      all            1        0.954151       1.0          NaN
# 44392  schizo            1        0.983499       1.0          SCZ
#
#                overlap
# 1219   AP3B2|PIGQ|SZT2
# 44817      TPRKB|WDR73
# 1644       TPRKB|WDR73
# 4075       DDHD2|NT5C2
# 2283         ARL3|SUFU
# ...                ...
# 47281            ATXN7
# 45886             ANK3
# 4108             ATXN7
# 2713              ANK3
# 44392             SZT2
#
# [133 rows x 12 columns]

# %%
mono_poly_dz_df_filt.mono_dz.unique().shape
# Out:
# (58,)

# %%
# sorted(mono_poly_dz_df_filt.mono_dz.unique())

# %%
filt_list_monodz = [
 'Aicardi-Goutieres syndrome',
 'Al Kaissi syndrome',
 'Amyotrophic lateral sclerosis susceptibility to',
 'Birk-Landau-Perez syndrome',
 'CATSHL syndrome',
 'Charcot-Marie-Tooth disease axonal type 2A2A',
 'Charcot-Marie-Tooth disease axonal type 2A2B',
 'Charcot-Marie-Tooth disease axonal type 2U',
 'Charcot-Marie-Tooth disease axonal type 2W',
#  'Codeine sensitivity',
 'Creutzfeldt-Jakob disease variant resistance to',
 'Developmental and epileptic encephalopathy',
#  'Dystonia-1 modifier of}',
#  'Dystonia-1 torsion',
 'Encephalitis/encephalopathy mild with reversible myelin vacuolization',
 'Encephalocraniocutaneous lipomatosis somatic mosaic',
 'Encephalopathy acute infection-induced herpes-specific susceptibility to',
 'Epilepsy nocturnal frontal lobe type',
 'Galloway-Mowat syndrome',
 'Gaze palsy familial horizontal with progressive scoliosis',
 'Glioblastoma somatic',
 'Hartsfield syndrome',
 'Hereditary motor and sensory neuropathy VIA',
 'Holoprosencephaly with or without pancreatic agenesis',
 'Homocystinuria due to MTHFR deficiency',
 'Hyperphosphatasia with mental retardation syndrome',
 'Hypersensitivity syndrome carbamazepine-induced susceptibility to',
 'Hypomagnesemia seizures and mental retardation',
 'Infantile cerebellar-retinal degeneration',
 'Intellectual developmental disorder autosomal recessive',
 'Joubert syndrome',
 'Lissencephaly',
 'Medulloblastoma desmoplastic',
 'Meningioma familial susceptibility to',
 'Menke-Hennekam syndrome',
 'Mental retardation autosomal recessive',
 'Mirror movements and/or agenesis of the corpus callosum',
 'Muenke syndrome',
 'Myoclonus familial',
 'Nestor-Guillermo progeria syndrome',
 'Neural tube defects folate-sensitive susceptibility to',
 'Neural tube defects susceptibility to',
 'Neurodevelopmental disorder with absent language and variable seizures',
 'Neurodevelopmental disorder with dysmorphic facies impaired speech and hypotonia',
 'Neurodevelopmental disorder with microcephaly cortical malformations and spasticity',
 'Neurodevelopmental disorder with microcephaly seizures and cortical atrophy',
 'Neurodevelopmental disorder with or without anomalies of the brain eye or heart',
 'Neuropathy hereditary sensory and autonomic type IA',
 'Parkinson disease autosomal recessive early-onset',
 'Pituitary adenoma ACTH-secreting somatic',
 'Pontocerebellar hypoplasia type',
 'Proteus syndrome somatic',
 'Rubinstein-Taybi syndrome',
 'SADDAN',
 'Short stature brachydactyly intellectual developmental disability and seizures',
 'Short stature developmental delay and congenital heart defects',
 'Spastic paraplegia autosomal recessive',
 'Spinocerebellar ataxia',
 'Thauvin-Robinet-Faivre syndrome',
 'Trigonocephaly',
 'Vissers-Bodmer syndrome']

# %%
for x in filt_list_monodz:
    print(x)
# Out:
# Aicardi-Goutieres syndrome
# Al Kaissi syndrome
# Amyotrophic lateral sclerosis susceptibility to
# Birk-Landau-Perez syndrome
# CATSHL syndrome
# Charcot-Marie-Tooth disease axonal type 2A2A
# Charcot-Marie-Tooth disease axonal type 2A2B
# Charcot-Marie-Tooth disease axonal type 2U
# Charcot-Marie-Tooth disease axonal type 2W
# Creutzfeldt-Jakob disease variant resistance to
# Developmental and epileptic encephalopathy
# Encephalitis/encephalopathy mild with reversible myelin vacuolization
# Encephalocraniocutaneous lipomatosis somatic mosaic
# Encephalopathy acute infection-induced herpes-specific susceptibility to
# Epilepsy nocturnal frontal lobe type
# Galloway-Mowat syndrome
# Gaze palsy familial horizontal with progressive scoliosis
# Glioblastoma somatic
# Hartsfield syndrome
# Hereditary motor and sensory neuropathy VIA
# Holoprosencephaly with or without pancreatic agenesis
# Homocystinuria due to MTHFR deficiency
# Hyperphosphatasia with mental retardation syndrome
# Hypersensitivity syndrome carbamazepine-induced susceptibility to
# Hypomagnesemia seizures and mental retardation
# Infantile cerebellar-retinal degeneration
# Intellectual developmental disorder autosomal recessive
# Joubert syndrome
# Lissencephaly
# Medulloblastoma desmoplastic
# Meningioma familial susceptibility to
# Menke-Hennekam syndrome
# Mental retardation autosomal recessive
# Mirror movements and/or agenesis of the corpus callosum
# Muenke syndrome
# Myoclonus familial
# Nestor-Guillermo progeria syndrome
# Neural tube defects folate-sensitive susceptibility to
# Neural tube defects susceptibility to
# Neurodevelopmental disorder with absent language and variable seizures
# Neurodevelopmental disorder with dysmorphic facies impaired speech and hypotonia
# Neurodevelopmental disorder with microcephaly cortical malformations and spasticity
# Neurodevelopmental disorder with microcephaly seizures and cortical atrophy
# Neurodevelopmental disorder with or without anomalies of the brain eye or heart
# Neuropathy hereditary sensory and autonomic type IA
# Parkinson disease autosomal recessive early-onset
# Pituitary adenoma ACTH-secreting somatic
# Pontocerebellar hypoplasia type
# Proteus syndrome somatic
# Rubinstein-Taybi syndrome
# SADDAN
# Short stature brachydactyly intellectual developmental disability and seizures
# Short stature developmental delay and congenital heart defects
# Spastic paraplegia autosomal recessive
# Spinocerebellar ataxia
# Thauvin-Robinet-Faivre syndrome
# Trigonocephaly
# Vissers-Bodmer syndrome

# %%
len(filt_list_monodz)
# Out:
# 58

# %%
mono_poly_dz_df_filt_neuro = mono_poly_dz_df_filt[mono_poly_dz_df_filt.mono_dz.isin(filt_list_monodz)]
mono_poly_dz_df_filt.shape, mono_poly_dz_df_filt_neuro.shape
# Out:
# ((133, 12), (133, 12))

# %%
mono_poly_dz_df_filt_neuro[['mono_dz','mono_geneset']].reset_index(drop='True').to_csv(os.path.join(save_dir, 'mono_dz.csv')) # suppl table

# %%
mono_poly_dz_df_filt_neuro.sort_values('len_mono',ascending=False)[:20]
# Out:
#                                           mono_dz  poly_dz  \
# 1219   Developmental and epileptic encephalopathy      NaN
# 49189  Developmental and epileptic encephalopathy      NaN
# 10813  Developmental and epileptic encephalopathy      NaN
# 44392  Developmental and epileptic encephalopathy      NaN
# 45886      Mental retardation autosomal recessive      NaN
# 2713       Mental retardation autosomal recessive      NaN
# 26698      Mental retardation autosomal recessive      NaN
# 47248      Spastic paraplegia autosomal recessive      NaN
# 4075       Spastic paraplegia autosomal recessive      NaN
# 11877                            Joubert syndrome      NaN
# 2283                             Joubert syndrome      NaN
# 21471                            Joubert syndrome      NaN
# 45456                            Joubert syndrome      NaN
# 4108                       Spinocerebellar ataxia      NaN
# 47281                      Spinocerebellar ataxia      NaN
# 3630              Pontocerebellar hypoplasia type      NaN
# 46803             Pontocerebellar hypoplasia type      NaN
# 43292                  Aicardi-Goutieres syndrome      NaN
# 119                    Aicardi-Goutieres syndrome      NaN
# 1644                      Galloway-Mowat syndrome      NaN
#
#                                             mono_geneset  \
# 1219   [AARS, AARS1, ACTL6B, ADAM22, ALG13, AP3B2, AR...
# 49189  [AARS, AARS1, ACTL6B, ADAM22, ALG13, AP3B2, AR...
# 10813  [AARS, AARS1, ACTL6B, ADAM22, ALG13, AP3B2, AR...
# 44392  [AARS, AARS1, ACTL6B, ADAM22, ALG13, AP3B2, AR...
# 45886  [2E4, ADAT3, ANK3, BB1, BSSP3, C12orf4, C17orf...
# 2713   [2E4, ADAT3, ANK3, BB1, BSSP3, C12orf4, C17orf...
# 26698  [2E4, ADAT3, ANK3, BB1, BSSP3, C12orf4, C17orf...
# 47248  [ALS5, AP4B1, AP4E1, AP4M1, AP4S1, AP5Z1, ARL6...
# 4075   [ALS5, AP4B1, AP4E1, AP4M1, AP4S1, AP5Z1, ARL6...
# 11877  [3H11AG, ACLS, AGBK, AHI1, ALS2CR4, ARFL3, ARL...
# 2283   [3H11AG, ACLS, AGBK, AHI1, ALS2CR4, ARFL3, ARL...
# 21471  [3H11AG, ACLS, AGBK, AHI1, ALS2CR4, ARFL3, ARL...
# 45456  [3H11AG, ACLS, AGBK, AHI1, ALS2CR4, ARFL3, ARL...
# 4108   [ADMD, AFG3L2, ASL13, ATX1, ATX2, ATXN1, ATXN1...
# 47281  [ADMD, AFG3L2, ASL13, ATX1, ATX2, ATXN1, ATXN1...
# 3630   [AMPD2, ANG2, CHMP1A, CLP1, COASY, HEAB, NBIA6...
# 46803  [AMPD2, ANG2, CHMP1A, CLP1, COASY, HEAB, NBIA6...
# 43292  [ADAR, AGS2, AGS3, AGS4, AGS5, AGS6, AGS7, AYP...
# 119    [ADAR, AGS2, AGS3, AGS4, AGS5, AGS6, AGS7, AYP...
# 1644   [FLJ20411, GAMOS1, GAMOS3, GAMOS4, GAMOS5, GAM...
#
#                                             poly_geneset  len_mono  len_poly  \
# 1219   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...       280       429
# 49189           [AP3B2, BOLA3, BOLA3-AS1, MTHFD2, TADA1]       280         5
# 10813  [ACADM, AGT, ARL3, AS3MT, CALHM2, CCDC78, CCHC...       280        46
# 44392  [ABCB9, ABCC8, ABHD16A, ABT1, AGER, AGT, AIF1,...       280       308
# 45886  [ABCB9, ABCC8, ABHD16A, ABT1, AGER, AGT, AIF1,...       151       308
# 2713   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...       151       429
# 26698  [ACO2, ADAMTS2, ANK3, ATP6V1D, CAST, CCDC122, ...       151        55
# 47248  [ABCB9, ABCC8, ABHD16A, ABT1, AGER, AGT, AIF1,...       137       308
# 4075   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...       137       429
# 11877  [ACADM, AGT, ARL3, AS3MT, CALHM2, CCDC78, CCHC...       127        46
# 2283   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...       127       429
# 21471  [ABCB9, ABCC8, ABHD16A, AGT, AIF1, APOPT1, ARL...       127       129
# 45456  [ABCB9, ABCC8, ABHD16A, ABT1, AGER, AGT, AIF1,...       127       308
# 4108   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...       124       429
# 47281  [ABCB9, ABCC8, ABHD16A, ABT1, AGER, AGT, AIF1,...       124       308
# 3630   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...        30       429
# 46803  [ABCB9, ABCC8, ABHD16A, ABT1, AGER, AGT, AIF1,...        30       308
# 43292  [ABCB9, ABCC8, ABHD16A, ABT1, AGER, AGT, AIF1,...        26       308
# 119    [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...        26       429
# 1644   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...        21       429
#
#         polydz  len_overlap  hypergeom_pval  pval_adj poly_dz_abbr  \
# 1219       all            3        0.923193       1.0          NaN
# 49189    traum            1        0.064011       1.0         PTSD
# 10813   attent            1        0.456203       1.0         ADHD
# 44392   schizo            1        0.983499       1.0          SCZ
# 45886   schizo            1        0.889928       1.0          SCZ
# 2713       all            1        0.954151       1.0          NaN
# 26698  depress            1        0.324081       1.0          MDD
# 47248   schizo            2        0.591493       1.0          SCZ
# 4075       all            2        0.765868       1.0          NaN
# 11877   attent            1        0.240661       1.0         ADHD
# 2283       all            2        0.728285       1.0          NaN
# 21471  bipolar            2        0.179582       1.0          BPD
# 45456   schizo            2        0.550270       1.0          SCZ
# 4108       all            1        0.920311       1.0          NaN
# 47281   schizo            1        0.836493       1.0          SCZ
# 3630       all            1        0.456996       1.0          NaN
# 46803   schizo            1        0.354123       1.0          SCZ
# 43292   schizo            1        0.315334       1.0          SCZ
# 119        all            1        0.410907       1.0          NaN
# 1644       all            2        0.066043       1.0          NaN
#
#                overlap
# 1219   AP3B2|PIGQ|SZT2
# 49189            AP3B2
# 10813             PIGQ
# 44392             SZT2
# 45886             ANK3
# 2713              ANK3
# 26698             ANK3
# 47248      DDHD2|NT5C2
# 4075       DDHD2|NT5C2
# 11877             ARL3
# 2283         ARL3|SUFU
# 21471        ARL3|SUFU
# 45456        ARL3|SUFU
# 4108             ATXN7
# 47281            ATXN7
# 3630              CLP1
# 46803             CLP1
# 43292         RNASEH2C
# 119           RNASEH2C
# 1644       TPRKB|WDR73

# %% [markdown]
# Note: most omim disease have little to know overlap (1% have an overlap of at least a gene)

# %% [markdown]
# # get universe length

# %%
mim2gene = pd.read_table(os.path.join(omim_dir, 'mim2gene.txt'), header=4).dropna()
print(mim2gene.shape)
mim2gene[:5]
# Out:
# (16014, 5)
#     # MIM Number MIM Entry Type (see FAQ 1.3 at https://omim.org/help/faq)  \
# 7         100640                                               gene
# 8         100650                                     gene/phenotype
# 9         100660                                               gene
# 10        100670                                               gene
# 12        100678                                               gene
#
#     Entrez Gene ID (NCBI) Approved Gene Symbol (HGNC)  \
# 7                   216.0                     ALDH1A1
# 8                   217.0                       ALDH2
# 9                   218.0                     ALDH3A1
# 10                  219.0                     ALDH1B1
# 12                   39.0                       ACAT2
#
#    Ensembl Gene ID (Ensembl)
# 7            ENSG00000165092
# 8            ENSG00000111275
# 9            ENSG00000108602
# 10           ENSG00000137124
# 12           ENSG00000120437

# %%
num_genes_universe = 21306# from the hngc website of known egenes#len(set(mim2gene['Entrez Gene ID (NCBI)']))
num_genes_universe
# Out:
# 21306

# %% [markdown]
# # B. hypergeeometric test intersecting genesets

# %%
from scipy.stats import hypergeom
from statsmodels.stats.multitest import fdrcorrection

# %%
def hypergeometric(x, N, n, G, alternative='greater'):
    
    """
    Parameters
    ----------
    x : int
        number of `good` elements observed in the sample
    N : int
        population size
    n : int
       sample size
    G : int
       hypothesized number of good elements in population
    alternative : {'greater', 'less', 'two-sided'}
       alternative hypothesis to test (default: 'greater')
    Returns
    -------
    float
       estimated p-value
    """
    if n < x:
        raise ValueError("Cannot observe more good elements than the sample size")
    if N < n:
        raise ValueError("Population size cannot be smaller than sample")
    if N < G:
        raise ValueError("Number of good elements can't exceed the population size")
    if G < x:
        raise ValueError("Number of observed good elements can't exceed the number in the population")

    assert alternative in ("two-sided", "less", "greater")
    if n < x:
        raise ValueError("Cannot observe more successes than the population size")

    plower = hypergeom.cdf(x, N, G, n)
    pupper = hypergeom.sf(x-1, N, G, n)
    if alternative == 'two-sided':
        pvalue = 2*np.min([plower, pupper, 0.5])
    elif alternative == 'greater':
        pvalue = pupper
    elif alternative == 'less':
        pvalue = plower
    return pvalue

# %%
mono_poly_dz_df_filt_neuro['hypergeom_pval'] = mono_poly_dz_df_filt_neuro.apply(lambda row:
                                                                   hypergeometric(row.len_overlap,num_genes_universe,  row.len_poly, row.len_mono),axis=1)
mono_poly_dz_df_filt_neuro.sort_values('hypergeom_pval',inplace=True)

# %%
mono_poly_dz_df_filt_neuro['poly_dz_abbr'] = mono_poly_dz_df_filt_neuro.polydz.map(dz_to_abbr_dict)

# %%
mono_poly_dz_df_filt_neuro[mono_poly_dz_df_filt_neuro.hypergeom_pval<0.05].mono_dz.unique().shape
# Out:
# (39,)

# %%
# do a bonferoni correction
mono_poly_dz_df_filt_neuro['pval_adj'] = mono_poly_dz_df_filt_neuro['hypergeom_pval'].apply(lambda pval: min(1, pval*mono_poly_dz_df_filt_neuro.shape[0]))

# %%
mono_poly_dz_df_filt_neuro.sort_values('len_overlap',ascending=False).to_csv('omim_enrichment/mono_poly_dz_df_filt.csv')

# %%
mono_poly_dz_df_filt_neuro.shape
# Out:
# (133, 12)

# %%
mono_poly_dz_df_filt_neuro
# Out:
#                                                  mono_dz  poly_dz  \
# 32698                                             SADDAN      NaN
# 31675                                    Muenke syndrome      NaN
# 29351                                    CATSHL syndrome      NaN
# 28903                                 Al Kaissi syndrome      NaN
# 27128  Neurodevelopmental disorder with or without an...      NaN
# ...                                                  ...      ...
# 45886             Mental retardation autosomal recessive      NaN
# 4108                              Spinocerebellar ataxia      NaN
# 1219          Developmental and epileptic encephalopathy      NaN
# 2713              Mental retardation autosomal recessive      NaN
# 44392         Developmental and epileptic encephalopathy      NaN
#
#                                             mono_geneset  \
# 32698                                       [ACH, FGFR3]
# 31675                                       [ACH, FGFR3]
# 29351                                       [ACH, FGFR3]
# 28903                            [ALSAS, CDK10, PISSLRE]
# 27128                                     [NEDBEH, RERE]
# ...                                                  ...
# 45886  [2E4, ADAT3, ANK3, BB1, BSSP3, C12orf4, C17orf...
# 4108   [ADMD, AFG3L2, ASL13, ATX1, ATX2, ATXN1, ATXN1...
# 1219   [AARS, AARS1, ACTL6B, ADAM22, ALG13, AP3B2, AR...
# 2713   [2E4, ADAT3, ANK3, BB1, BSSP3, C12orf4, C17orf...
# 44392  [AARS, AARS1, ACTL6B, ADAM22, ALG13, AP3B2, AR...
#
#                                             poly_geneset  len_mono  len_poly  \
# 32698  [ANKRD13B, BLMH, CABLES2, CDK10, CORO6, DRG2, ...         2        20
# 31675  [ANKRD13B, BLMH, CABLES2, CDK10, CORO6, DRG2, ...         2        20
# 29351  [ANKRD13B, BLMH, CABLES2, CDK10, CORO6, DRG2, ...         2        20
# 28903  [ANKRD13B, BLMH, CABLES2, CDK10, CORO6, DRG2, ...         3        20
# 27128  [ACO2, ADAMTS2, ANK3, ATP6V1D, CAST, CCDC122, ...         2        55
# ...                                                  ...       ...       ...
# 45886  [ABCB9, ABCC8, ABHD16A, ABT1, AGER, AGT, AIF1,...       151       308
# 4108   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...       124       429
# 1219   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...       280       429
# 2713   [AADAT, ABCB9, ABCC8, ABHD16A, ABT1, ACADM, AC...       151       429
# 44392  [ABCB9, ABCC8, ABHD16A, ABT1, AGER, AGT, AIF1,...       280       308
#
#         polydz  len_overlap  hypergeom_pval  pval_adj poly_dz_abbr  \
# 32698      ocd            1        0.001877  0.249584          OCD
# 31675      ocd            1        0.001877  0.249584          OCD
# 29351      ocd            1        0.001877  0.249584          OCD
# 28903      ocd            1        0.002814  0.374208          OCD
# 27128  depress            1        0.005156  0.685791          MDD
# ...        ...          ...             ...       ...          ...
# 45886   schizo            1        0.889928  1.000000          SCZ
# 4108       all            1        0.920311  1.000000          NaN
# 1219       all            3        0.923193  1.000000          NaN
# 2713       all            1        0.954151  1.000000          NaN
# 44392   schizo            1        0.983499  1.000000          SCZ
#
#                overlap
# 32698            FGFR3
# 31675            FGFR3
# 29351            FGFR3
# 28903            CDK10
# 27128             RERE
# ...                ...
# 45886             ANK3
# 4108             ATXN7
# 1219   AP3B2|PIGQ|SZT2
# 2713              ANK3
# 44392             SZT2
#
# [133 rows x 12 columns]

# %% [markdown]
# # C Venn diagram overall venn diagram

# %%
# [item for sublist in t for item in sublist]
mono_geneset_all = set([x for sublist in mono_poly_dz_df.mono_geneset.to_list() for x in sublist])
mono_geneset = set([x for sublist in mono_poly_dz_df_filt_neuro.mono_geneset.to_list() for x in sublist])
poly_genes = set(polydz_to_geneset['all'])
print(len(mono_geneset_all),len(mono_geneset), len(poly_genes))
# Out:
# 47 1109 619

# %%
print(len(mono_geneset.intersection(poly_genes)))
for x in sorted(mono_geneset.intersection(poly_genes)):
    print(x)
# Out:
# 51
# ACO2
# AKT1
# ANK3
# AP3B2
# ARC
# ARL3
# ATXN7
# BANF1
# CDK10
# CEP85L
# CHRNA2
# CLP1
# CNNM2
# CNOT1
# DCC
# DDHD2
# EP300
# ERBB2
# FGFR1
# FGFR3
# FIBP
# GNAI2
# HARS
# HLA-A
# HLA-DQB1
# IRF3
# MADD
# MARS
# MFN2
# MTHFD1
# MTHFR
# MYRF
# NEK1
# NT5C2
# PARK7
# PGAP3
# PIGQ
# PRMT7
# RERE
# RNASEH2C
# RSRC1
# SLC30A9
# SPTLC1
# SUFU
# SZT2
# TKT
# TMX2
# TPRKB
# VARS2
# WASF1
# WDR73

# %%
len(mono_geneset_all.union(poly_genes)),len(mono_geneset.intersection(poly_genes))
# Out:
# (666, 51)

# %%
gene_df = pd.DataFrame(pd.Series(gene_mono_poly_df_sel_cols_dzmerge.gene_sel.unique()))
gene_df['node_type'] = 'gene'
gene_df.columns = ['node','node_type']
dz_df = pd.DataFrame(pd.Series(gene_mono_poly_df_sel_cols_dzmerge.mono_dz.unique()))
dz_df['node_type'] = 'disease'
dz_df.columns = ['node','node_type']
gene_dz_df = pd.concat([gene_df, dz_df])
gene_dz_df.to_csv(os.path.join(save_dir, 'gene_dz_df.csv'))
# + gene_mono_poly_df_sel_cols_dzmerge.genesel.unique() +

# %%
gene_mono_poly_df_sel_cols.pivot_table(values='hypergeom_pval', index='mono_dz', columns='gene_sel', 
                         aggfunc=lambda x: len(x.unique())).fillna(0)
# Out:
# gene_sel                                           ABCC8  ACADM  ACO2  AGT  \
# mono_dz
# 46XY sex reversal                                    0.0    0.0   0.0  0.0
# Acyl-CoA dehydrogenase medium chain deficiency of    0.0    2.0   0.0  0.0
# Aicardi-Goutieres syndrome                           0.0    0.0   0.0  0.0
# Al Kaissi syndrome                                   0.0    0.0   0.0  0.0
# Amyotrophic lateral sclerosis susceptibility to      0.0    0.0   0.0  0.0
# ...                                                  ...    ...   ...  ...
# Spastic paraplegia autosomal recessive               0.0    0.0   0.0  0.0
# Spinocerebellar ataxia                               0.0    0.0   0.0  0.0
# Thauvin-Robinet-Faivre syndrome                      0.0    0.0   0.0  0.0
# Trigonocephaly                                       0.0    0.0   0.0  0.0
# Vissers-Bodmer syndrome                              0.0    0.0   0.0  0.0
#
# gene_sel                                           ANK3  AP3B2  APOPT1  ARL3  \
# mono_dz
# 46XY sex reversal                                   0.0    0.0     0.0   0.0
# Acyl-CoA dehydrogenase medium chain deficiency of   0.0    0.0     0.0   0.0
# Aicardi-Goutieres syndrome                          0.0    0.0     0.0   0.0
# Al Kaissi syndrome                                  0.0    0.0     0.0   0.0
# Amyotrophic lateral sclerosis susceptibility to     0.0    0.0     0.0   0.0
# ...                                                 ...    ...     ...   ...
# Spastic paraplegia autosomal recessive              0.0    0.0     0.0   0.0
# Spinocerebellar ataxia                              0.0    0.0     0.0   0.0
# Thauvin-Robinet-Faivre syndrome                     0.0    0.0     0.0   0.0
# Trigonocephaly                                      0.0    0.0     0.0   0.0
# Vissers-Bodmer syndrome                             0.0    0.0     0.0   0.0
#
# gene_sel                                           ATXN7  BANF1  ...  SPTLC1  \
# mono_dz                                                          ...
# 46XY sex reversal                                    0.0    0.0  ...     0.0
# Acyl-CoA dehydrogenase medium chain deficiency of    0.0    0.0  ...     0.0
# Aicardi-Goutieres syndrome                           0.0    0.0  ...     0.0
# Al Kaissi syndrome                                   0.0    0.0  ...     0.0
# Amyotrophic lateral sclerosis susceptibility to      0.0    0.0  ...     0.0
# ...                                                  ...    ...  ...     ...
# Spastic paraplegia autosomal recessive               0.0    0.0  ...     0.0
# Spinocerebellar ataxia                               2.0    0.0  ...     0.0
# Thauvin-Robinet-Faivre syndrome                      0.0    0.0  ...     0.0
# Trigonocephaly                                       0.0    0.0  ...     0.0
# Vissers-Bodmer syndrome                              0.0    0.0  ...     0.0
#
# gene_sel                                           SREBF1  SUFU  SZT2  TKT  \
# mono_dz
# 46XY sex reversal                                     0.0   0.0   0.0  0.0
# Acyl-CoA dehydrogenase medium chain deficiency of     0.0   0.0   0.0  0.0
# Aicardi-Goutieres syndrome                            0.0   0.0   0.0  0.0
# Al Kaissi syndrome                                    0.0   0.0   0.0  0.0
# Amyotrophic lateral sclerosis susceptibility to       0.0   0.0   0.0  0.0
# ...                                                   ...   ...   ...  ...
# Spastic paraplegia autosomal recessive                0.0   0.0   0.0  0.0
# Spinocerebellar ataxia                                0.0   0.0   0.0  0.0
# Thauvin-Robinet-Faivre syndrome                       0.0   0.0   0.0  0.0
# Trigonocephaly                                        0.0   0.0   0.0  0.0
# Vissers-Bodmer syndrome                               0.0   0.0   0.0  0.0
#
# gene_sel                                           TMX2  TPRKB  VARS2  WASF1  \
# mono_dz
# 46XY sex reversal                                   0.0    0.0    0.0    0.0
# Acyl-CoA dehydrogenase medium chain deficiency of   0.0    0.0    0.0    0.0
# Aicardi-Goutieres syndrome                          0.0    0.0    0.0    0.0
# Al Kaissi syndrome                                  0.0    0.0    0.0    0.0
# Amyotrophic lateral sclerosis susceptibility to     0.0    0.0    0.0    0.0
# ...                                                 ...    ...    ...    ...
# Spastic paraplegia autosomal recessive              0.0    0.0    0.0    0.0
# Spinocerebellar ataxia                              0.0    0.0    0.0    0.0
# Thauvin-Robinet-Faivre syndrome                     0.0    0.0    0.0    0.0
# Trigonocephaly                                      0.0    0.0    0.0    0.0
# Vissers-Bodmer syndrome                             0.0    0.0    0.0    0.0
#
# gene_sel                                           WDR73
# mono_dz
# 46XY sex reversal                                    0.0
# Acyl-CoA dehydrogenase medium chain deficiency of    0.0
# Aicardi-Goutieres syndrome                           0.0
# Al Kaissi syndrome                                   0.0
# Amyotrophic lateral sclerosis susceptibility to      0.0
# ...                                                  ...
# Spastic paraplegia autosomal recessive               0.0
# Spinocerebellar ataxia                               0.0
# Thauvin-Robinet-Faivre syndrome                      0.0
# Trigonocephaly                                       0.0
# Vissers-Bodmer syndrome                              0.0
#
# [78 rows x 69 columns]
